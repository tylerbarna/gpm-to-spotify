# %%
import json
import pandas as pd
import sqlite3

# %% [markdown]
# Import Data

# %%
with open('data/spotifyData.json') as f:
    sData = json.load(f)

with open('data/gpmData.json') as f:
    gData = json.load(f)

# %%
sdf = pd.DataFrame(sData)
display(sdf.head())
display(sdf.columns)

gdf = pd.DataFrame(gData)
display(gdf.head())
# Out:
#                      ts     username  \
# 0  2022-05-21T20:35:37Z  12100051434
# 1  2022-03-02T00:33:48Z  12100051434
# 2  2021-04-10T00:42:58Z  12100051434
# 3  2022-06-16T17:42:55Z  12100051434
# 4  2021-03-20T16:42:32Z  12100051434
#
#                                      platform  ms_played conn_country  \
# 0  Android OS 12 API 32 (Google, Pixel 6 Pro)     208173           US
# 1  Android OS 12 API 32 (Google, Pixel 6 Pro)     256986           US
# 2          Windows 10 (10.0.19042; x64; AppX)     134746           US
# 3  Android OS 12 API 32 (Google, Pixel 6 Pro)       6577           US
# 4   Android OS 11 API 30 (Google, Pixel 2 XL)     422230           US
#
#   ip_addr_decrypted user_agent_decrypted         master_metadata_track_name  \
# 0   209.107.189.199              unknown                Headfirst for Halos
# 1   209.107.181.167              unknown                      The Good Life
# 2      173.61.17.84              unknown                          Dies Irae
# ...
